# %%
from pathlib import Path

# %%
path = Path.home() / "Code" / "artwork_data.csv"
path
# Out:
# PosixPath('/Users/kaya/Code/artwork_data.csv')

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    path, 
    nrows=5, 
    index_col="id",
    usecols=[
        "id",
        "artist",
        "title",
        "medium",
        "year",
        "width",
        "height",
        "units"
    ]
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 1035 to 1039
# Data columns (total 7 columns):
# artist    5 non-null object
# title     5 non-null object
# medium    5 non-null object
# year      2 non-null float64
# width     5 non-null int64
# height    5 non-null int64
# units     5 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 320.0+ bytes

# %%
df.isnull()
# Out:
#       artist  title  medium   year  width  height  units
# id
# 1035   False  False   False   True  False   False  False
# 1036   False  False   False   True  False   False  False
# 1037   False  False   False  False  False   False  False
# 1038   False  False   False   True  False   False  False
# 1039   False  False   False  False  False   False  False

# %%
df.fillna({"year": 0}).astype({"year":np.int64})
# Out:
#               artist                                              title  \
# id
# 1035   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 1037   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 1038   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 1039  Blake, William  The Circle of the Lustful: Francesca da Rimini...
#
#                                                  medium  year  width  height  \
# id
# 1035  Watercolour, ink, chalk and graphite on paper....     0    394     419
# 1036                                  Graphite on paper     0    311     213
# 1037        Graphite on paper. Verso: graphite on paper  1785    343     467
# 1038                                  Graphite on paper     0    318     394
# 1039                            Line engraving on paper  1826    243     335
#
#      units
# id
# 1035    mm
# 1036    mm
# 1037    mm
# ...

# %%
df = pd.read_csv(
    path, 
    nrows=5, 
    index_col="id",
    usecols=[
        "id",
        "artist",
        "title",
        "medium",
        "year",
        "acquisitionYear",
        "width",
        "height",
        "units"
    ]
)
df
# Out:
#               artist                                              title  \
# id
# 1035   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 1037   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 1038   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 1039  Blake, William  The Circle of the Lustful: Francesca da Rimini...
#
#                                                  medium    year  \
# id
# 1035  Watercolour, ink, chalk and graphite on paper....     NaN
# 1036                                  Graphite on paper     NaN
# 1037        Graphite on paper. Verso: graphite on paper  1785.0
# 1038                                  Graphite on paper     NaN
# 1039                            Line engraving on paper  1826.0
#
#       acquisitionYear  width  height units
# id
# 1035             1922    394     419    mm
# 1036             1922    311     213    mm
# ...

# %%
df.to_pickle("data_frame.pickle")

# %%
pd.DataFrame([("Alice", 32), ("Bob", 17)], columns=["Name", "Age"])
# Out:
#     Name  Age
# 0  Alice   32
# 1    Bob   17
